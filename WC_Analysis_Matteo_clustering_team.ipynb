# %%
#import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from kneed import KneeLocator
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import seaborn as sns
import warnings
from sklearn.cluster import DBSCAN # To instantiate and fit the model
from sklearn.metrics import pairwise_distances # For Model evaluation
from sklearn.neighbors import NearestNeighbors # For Hyperparameter Tuning
warnings.filterwarnings('ignore')

#PATH dove andare a leggere e a scrivere
PATH_TO_WRITE_ETL = "./dataset_modificato/"
PATH_FROM_READ_ETL = "./dataset_originale/"
PATH_FROM_READ_ANALYSIS = "./dataset_modificato/"

# %%
df_team_stats = pd.read_csv("./ETL_Mat/stats_team.csv")


plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(df_team_stats['goal_differential'], kde=True, bins=20)
plt.title('Distribuzione differenza reti', fontsize = 20)
plt.xlabel('Range dei goal fatti e subiti')
plt.ylabel('Count')


plt.subplot(1, 2, 2)
sns.set(style = 'whitegrid')
sns.distplot(df_team_stats['win_lose_differential'], color = 'red',kde=True, bins=15)
plt.title('Distribuzione della differenza tra vittorie e sconfitte', fontsize = 20)
plt.xlabel('Range della differenza tra vittorie e sconfitte')
plt.ylabel('Count')
plt.show()

# %%
sns.pairplot(df_team_stats.drop(["team_id"], axis=1))

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df_team_stats.drop(["team_id"], axis=1).corr(), cmap = 'Blues', annot = True, annot_kws={"fontsize": 16})
plt.title('Heatmap', fontsize = 20)
plt.show()

# %%
#normalizzazione
scaler = StandardScaler()
df_team_stats_std = scaler.fit_transform(df_team_stats.drop(["team_id"], axis=1))
print(np.mean(df_team_stats_std),np.std(df_team_stats_std))
print(df_team_stats_std.shape)
# Out:
# -9.39871343598016e-18 1.0
# (84, 9)

# %%
pca = PCA()
pca.fit(df_team_stats_std)
pca.explained_variance_ratio_

plt.figure(figsize=(10,8))
plt.plot(range(1,df_team_stats_std.shape[1]+1),pca.explained_variance_ratio_.cumsum(),marker='o',linestyle='--')
plt.title('Varianza tra le componenti')
plt.xlabel('Numero di componenti')
plt.ylabel('Varianza comulativa')
# Out:
# Text(0, 0.5, 'Varianza comulativa')

# %%
#prendiamo l'80% della varianza comulativa quindi 4 componenti
pca = PCA(n_components = 3, svd_solver='full')
pca.fit(df_team_stats_std)
# Out:
# PCA(n_components=3, svd_solver='full')

# %%
scores_pca = pca.transform(df_team_stats_std)
print(scores_pca.shape)
# Out:
# (84, 3)

# %%
#Elbow Method
wcss = []
for i in range(1,50):
    kmeans_pca = KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1,50),wcss,marker='o',linestyle='--')
plt.title('K-Means utilizzando PCA')
plt.xlabel('Numero di cluster')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
#numero di cluster
kl = KneeLocator(range(1,50),wcss,curve="convex",direction="decreasing")
print(kl.elbow)
kmeans_pca = KMeans(n_clusters=kl.elbow,init='k-means++',random_state=42)
kmeans_pca.fit(scores_pca)
# Out:
# 6
# KMeans(n_clusters=6, random_state=42)

# %%
#visualizzazione risultati
df_segm_pca_kmeans = pd.concat([df_team_stats.reset_index(drop=True),pd.DataFrame(scores_pca)],axis=1)
df_segm_pca_kmeans.columns.values[-3:] = ['C-1','C-2','C-3']
df_segm_pca_kmeans['Segm K-means PCA'] = kmeans_pca.labels_
df_segm_pca_kmeans['Segment'] = df_segm_pca_kmeans['Segm K-means PCA'].map({0:'primo',1:'secondo',2:'terzo',
3:'quarto',4:'quinto',5:'sesto'
})
#,8:'nono',9:'decimo'
df_segm_pca_kmeans.head()
# Out:
#   team_id  goal_differential  win_lose_differential  yellow_card  red_card  \
# 0    T-01                 -6                     -4           19         2
# 1    T-02                 -1                     -1           12         1
# 2    T-03                 44                     23          122         7
# 3    T-04                -18                     -8           33         4
# 4    T-05                 -4                     -1           23         1
#
#    player_per_teams  world_cup_appearence  finals_reached  finals_win  \
# 0                57                     4               0           0
# 1                17                     1               0           0
# 2               221                    17               5           2
# 3                63                     5               0           0
# 4                93                     7               0           0
#
#    different_managers       C-1       C-2       C-3  Segm K-means PCA Segment
# 0                   4 -0.829345  0.154852  0.194682                 2   terzo
# 1                   1 -1.626367 -0.924343  0.290076                 0   primo
# 2                  15  7.724136  0.386504  0.183538                 5   sesto
# 3                   5 -0.457997  1.056137  0.986325                 2   terzo
# 4                   8 -0.003508  0.740041 -0.786471                 2   terzo

# %%
x_axis=df_segm_pca_kmeans['C-1']
y_axis=df_segm_pca_kmeans['C-2']
plt.figure(figsize=(10,8))
sns.scatterplot(x=x_axis,y=y_axis,hue=df_segm_pca_kmeans['Segment'],palette='colorblind')
plt.title('Clusters')
plt.show()

# %%
kmeans_silhuouette = silhouette_score(scores_pca,kmeans_pca.labels_).round(2)
print(kmeans_silhuouette)
from yellowbrick.cluster import SilhouetteVisualizer


# Instantiate the clustering model and visualizer
model = KMeans(6, random_state=42)
visualizer = SilhouetteVisualizer(model, colors='yellowbrick')

plt.figure(figsize=(15,8))
visualizer.fit(scores_pca)        # Fit the data to the visualizer
visualizer.show()        # Finalize and render the figure
# Out:
# 0.45
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 84 Samples in 6 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
#df_players = pd.read_csv(PATH_FROM_READ_ANALYSIS+"match.csv")
#df_segm_pca_kmeans_2 = df_players[["player_id","family_name","given_name"]].merge(df_segm_pca_kmeans,how="right",on="player_id")
df2 = pd.DataFrame()
#df_segm_pca_kmeans[df_segm_pca_kmeans["Segm K-means PCA"]==0].describe()
for i in range(0,7):
    df = df_segm_pca_kmeans[df_segm_pca_kmeans["Segm K-means PCA"]==i]
    df.drop(["C-1","C-2"],axis=1,inplace=True)
    df.to_csv("clusters/clusters_team/cluster_"+str(i)+".csv",index=False)
    #df = df[["total_games_played","n_minutes_played","n_tournaments","n_tournaments_played","total_final_match_played","n_wc_wins","total_goals","total_penalty_scored"]]
    #,"yellow_card","red_card","total_own_goals"
    #average = df.mean()
    #average["group"] = i
    #total = df.count()
    #average.name = 'mean'
    #df2 = df2.append(average)
#df2

# %%
#DB-SCAN

from sklearn.neighbors import NearestNeighbors
import numpy as np

neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(scores_pca)
distances, indices = nbrs.kneighbors(scores_pca)

distances = np.sort(distances, axis=0)
plt.figure(figsize=(12,8))
plt.plot(distances[:,1])
print(scores_pca.shape)
# Out:
# (84, 3)

# %%
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=2.3, min_samples=5).fit(scores_pca)
ymeans = db.labels_
print(set(ymeans))
df_segm_pca_dbScan= pd.concat([df_team_stats.reset_index(drop=True),pd.DataFrame(ymeans)],axis=1)
df2 = pd.DataFrame()
for i in range(-1,len(set(ymeans))-1):
    df = df_segm_pca_dbScan[df_segm_pca_dbScan[0]==i]
    df.to_csv("clusters/cluster_team_dbscan/cluster_"+str(i)+".csv",index=False)
    #df = df[["total_games_played","n_minutes_played","n_tournaments","n_tournaments_played","total_final_match_played","n_wc_wins","total_goals","total_penalty_scored"]]
    #,"yellow_card","red_card","total_own_goals"
    #average = df.mean()
    #total = df.count()
    #average.name = 'mean'
    #total.name = 'total'
    #df2 = df2.append(average)
    #df2 = df2.append(total)
dbscan_silhuouette = silhouette_score(scores_pca,db.labels_).round(2)
print(dbscan_silhuouette)
#df2

#db = DBSCAN(eps=1.8, min_samples=5)
#visualizer = SilhouetteVisualizer(db, colors='yellowbrick',estimator=db)

#plt.figure(figsize=(15,8))
#visualizer.fit(scores_pca)        # Fit the data to the visualizer
#visualizer.show()
# Out:
# {0, 1, -1}
# 0.59

# %%
#Metodo per trovare eps
def get_metrics(eps, min_samples, dataset, iter_):
    
    # Fitting ======================================================================
    
    dbscan_model_ = DBSCAN( eps = eps, min_samples = min_samples)
    dbscan_model_.fit(dataset)
    
    # Mean Noise Point Distance metric =============================================
    noise_indices = dbscan_model_.labels_ == -1
    
    if True in noise_indices:
        neighboors = NearestNeighbors(n_neighbors = 6).fit(dataset)
        distances, indices = neighboors.kneighbors(dataset)
        noise_distances = distances[noise_indices, 1:]
        noise_mean_distance = round(noise_distances.mean(), 3)
    else:
        noise_mean_distance = None
        
    # Number of found Clusters metric ==============================================
    
    number_of_clusters = len(set(dbscan_model_.labels_[dbscan_model_.labels_ >= 0]))
    
    # Log ==========================================================================
    
    print("%3d | Tested with eps = %3s and min_samples = %3s | %5s %4s" % (iter_, eps, min_samples, str(noise_mean_distance), number_of_clusters))
        
    return(noise_mean_distance, number_of_clusters)

# %%
eps_to_test = [round(eps,1) for eps in np.arange(2, 3, 0.1)]
min_samples_to_test = range(5, 50, 5)

print("EPS:", eps_to_test)
print("MIN_SAMPLES:", list(min_samples_to_test))
# Dataframe per la metrica sulla distanza media dei noise points dai K punti più vicini
results_noise = pd.DataFrame( 
    data = np.zeros((len(eps_to_test),len(min_samples_to_test))), # Empty dataframe
    columns = min_samples_to_test, 
    index = eps_to_test
)

# Dataframe per la metrica sul numero di cluster
results_clusters = pd.DataFrame( 
    data = np.zeros((len(eps_to_test),len(min_samples_to_test))), # Empty dataframe
    columns = min_samples_to_test, 
    index = eps_to_test
)
iter_ = 0

print("ITER| INFO%s |  DIST    CLUS" % (" "*39))
print("-"*65)

for eps in eps_to_test:
    for min_samples in min_samples_to_test:
        
        iter_ += 1
        
        # Calcolo le metriche
        noise_metric, cluster_metric = get_metrics(eps, min_samples, scores_pca, iter_)
        
        # Inserisco i risultati nei relativi dataframe
        results_noise.loc[eps, min_samples] = noise_metric
        results_clusters.loc[eps, min_samples] = cluster_metric
# Out:
# EPS: [2.0, 2.1, 2.2, 2.3, 2.4, 2.5, 2.6, 2.7, 2.8, 2.9]
# MIN_SAMPLES: [5, 10, 15, 20, 25, 30, 35, 40, 45]
# ITER| INFO                                        |  DIST    CLUS
# -----------------------------------------------------------------
#   1 | Tested with eps = 2.0 and min_samples =   5 | 3.237    1
#   2 | Tested with eps = 2.0 and min_samples =  10 | 3.137    1
#   3 | Tested with eps = 2.0 and min_samples =  15 | 3.034    1
#   4 | Tested with eps = 2.0 and min_samples =  20 | 3.034    1
#   5 | Tested with eps = 2.0 and min_samples =  25 | 3.034    1
#   6 | Tested with eps = 2.0 and min_samples =  30 | 3.034    1
#   7 | Tested with eps = 2.0 and min_samples =  35 | 2.602    1
#   8 | Tested with eps = 2.0 and min_samples =  40 | 2.602    1
#   9 | Tested with eps = 2.0 and min_samples =  45 | 2.539    1
#  10 | Tested with eps = 2.1 and min_samples =   5 | 3.237    1
#  11 | Tested with eps = 2.1 and min_samples =  10 | 3.237    1
#  12 | Tested with eps = 2.1 and min_samples =  15 | 3.115    1
#  13 | Tested with eps = 2.1 and min_samples =  20 | 3.115    1
#  14 | Tested with eps = 2.1 and min_samples =  25 | 3.115    1
#  15 | Tested with eps = 2.1 and min_samples =  30 | 3.115    1
#  16 | Tested with eps = 2.1 and min_samples =  35 | 2.736    1
#  17 | Tested with eps = 2.1 and min_samples =  40 | 2.736    1
#  18 | Tested with eps = 2.1 and min_samples =  45 | 2.602    1
#  19 | Tested with eps = 2.2 and min_samples =   5 | 3.237    1
#  20 | Tested with eps = 2.2 and min_samples =  10 | 3.237    1
#  21 | Tested with eps = 2.2 and min_samples =  15 | 3.115    1
#  22 | Tested with eps = 2.2 and min_samples =  20 | 3.115    1
#  23 | Tested with eps = 2.2 and min_samples =  25 | 3.115    1
#  24 | Tested with eps = 2.2 and min_samples =  30 | 3.115    1
#  25 | Tested with eps = 2.2 and min_samples =  35 | 3.115    1
#  26 | Tested with eps = 2.2 and min_samples =  40 |  2.85    1
#  27 | Tested with eps = 2.2 and min_samples =  45 | 2.696    1
#  28 | Tested with eps = 2.3 and min_samples =   5 |  4.52    2
#  29 | Tested with eps = 2.3 and min_samples =  10 | 3.317    1
#  30 | Tested with eps = 2.3 and min_samples =  15 | 3.237    1
#  31 | Tested with eps = 2.3 and min_samples =  20 | 3.115    1
#  32 | Tested with eps = 2.3 and min_samples =  25 | 3.115    1
#  33 | Tested with eps = 2.3 and min_samples =  30 | 3.115    1
#  34 | Tested with eps = 2.3 and min_samples =  35 | 3.115    1
#  35 | Tested with eps = 2.3 and min_samples =  40 |  2.85    1
#  36 | Tested with eps = 2.3 and min_samples =  45 | 2.799    1
#  37 | Tested with eps = 2.4 and min_samples =   5 |  4.52    2
#  38 | Tested with eps = 2.4 and min_samples =  10 | 3.317    1
#  39 | Tested with eps = 2.4 and min_samples =  15 | 3.237    1
#  40 | Tested with eps = 2.4 and min_samples =  20 | 3.237    1
#  41 | Tested with eps = 2.4 and min_samples =  25 | 3.115    1
#  42 | Tested with eps = 2.4 and min_samples =  30 | 3.115    1
#  43 | Tested with eps = 2.4 and min_samples =  35 | 3.115    1
#  44 | Tested with eps = 2.4 and min_samples =  40 | 2.968    1
#  45 | Tested with eps = 2.4 and min_samples =  45 | 2.968    1
#  46 | Tested with eps = 2.5 and min_samples =   5 | 5.037    1
#  47 | Tested with eps = 2.5 and min_samples =  10 | 3.361    1
#  48 | Tested with eps = 2.5 and min_samples =  15 | 3.361    1
#  49 | Tested with eps = 2.5 and min_samples =  20 | 3.237    1
#  50 | Tested with eps = 2.5 and min_samples =  25 | 3.237    1
#  51 | Tested with eps = 2.5 and min_samples =  30 | 3.115    1
#  52 | Tested with eps = 2.5 and min_samples =  35 | 3.115    1
#  53 | Tested with eps = 2.5 and min_samples =  40 | 3.115    1
#  54 | Tested with eps = 2.5 and min_samples =  45 | 3.115    1
#  55 | Tested with eps = 2.6 and min_samples =   5 | 5.037    1
#  56 | Tested with eps = 2.6 and min_samples =  10 | 3.361    1
#  57 | Tested with eps = 2.6 and min_samples =  15 | 3.361    1
#  58 | Tested with eps = 2.6 and min_samples =  20 | 3.237    1
#  59 | Tested with eps = 2.6 and min_samples =  25 | 3.237    1
#  60 | Tested with eps = 2.6 and min_samples =  30 | 3.237    1
#  61 | Tested with eps = 2.6 and min_samples =  35 | 3.237    1
#  62 | Tested with eps = 2.6 and min_samples =  40 | 3.237    1
#  63 | Tested with eps = 2.6 and min_samples =  45 | 3.115    1
#  64 | Tested with eps = 2.7 and min_samples =   5 | 5.037    1
#  65 | Tested with eps = 2.7 and min_samples =  10 | 4.083    1
#  66 | Tested with eps = 2.7 and min_samples =  15 | 3.517    1
#  67 | Tested with eps = 2.7 and min_samples =  20 | 3.391    1
#  68 | Tested with eps = 2.7 and min_samples =  25 | 3.391    1
#  69 | Tested with eps = 2.7 and min_samples =  30 | 3.345    1
#  70 | Tested with eps = 2.7 and min_samples =  35 | 3.237    1
#  71 | Tested with eps = 2.7 and min_samples =  40 | 3.237    1
#  72 | Tested with eps = 2.7 and min_samples =  45 | 3.237    1
#  73 | Tested with eps = 2.8 and min_samples =   5 | 5.037    1
#  74 | Tested with eps = 2.8 and min_samples =  10 | 4.083    1
#  75 | Tested with eps = 2.8 and min_samples =  15 | 3.775    1
#  76 | Tested with eps = 2.8 and min_samples =  20 | 3.775    1
#  77 | Tested with eps = 2.8 and min_samples =  25 | 3.595    1
#  78 | Tested with eps = 2.8 and min_samples =  30 | 3.345    1
#  79 | Tested with eps = 2.8 and min_samples =  35 | 3.345    1
#  80 | Tested with eps = 2.8 and min_samples =  40 | 3.345    1
#  81 | Tested with eps = 2.8 and min_samples =  45 | 3.237    1
#  82 | Tested with eps = 2.9 and min_samples =   5 | 5.037    1
#  83 | Tested with eps = 2.9 and min_samples =  10 | 4.561    1
#  84 | Tested with eps = 2.9 and min_samples =  15 | 3.775    1
#  85 | Tested with eps = 2.9 and min_samples =  20 | 3.775    1
#  86 | Tested with eps = 2.9 and min_samples =  25 | 3.775    1
#  87 | Tested with eps = 2.9 and min_samples =  30 | 3.391    1
#  88 | Tested with eps = 2.9 and min_samples =  35 | 3.345    1
#  89 | Tested with eps = 2.9 and min_samples =  40 | 3.345    1
#  90 | Tested with eps = 2.9 and min_samples =  45 | 3.345    1

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,8) )

sns.heatmap(results_noise, annot = True, ax = ax1, cbar = False).set_title("METRIC: Mean Noise Points Distance")
sns.heatmap(results_clusters, annot = True, ax = ax2, cbar = False).set_title("METRIC: Number of clusters")

ax1.set_xlabel("N"); ax2.set_xlabel("N")
ax1.set_ylabel("EPSILON"); ax2.set_ylabel("EPSILON")
#plt.rcParams['font.size'] = '20'
plt.tight_layout(); plt.show()
